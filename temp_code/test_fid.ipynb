# %%
import sys
import os

# Add the parent directory to the system path
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
import numpy as np
from evaluation.sample import compute_stat,fid

# %%
sample = np.load('../savings/glow_mrs/sample.npy')
mu_sample, sigma_sample = compute_stat(sample)

# %%
print(np.max(mu_sample))
# Out:
# 2.0165677e+16

# %%
from datasets import MRSDataset
from torch.utils.data import DataLoader

# %%
true_dataset = MRSDataset('../data/', split='train')
mu_true, sigma_true = compute_stat(true_dataset)
print(mu_true.shape, sigma_true.shape)
# Out:
# (512,) (512, 512)

# %%
fid_sample = fid(mu_sample, sigma_sample, mu_true, sigma_true)
print(fid_sample)
# Out:
# 10.308911617981481
