# %%
import sys
import os

# Add the parent directory to the system path
sys.path.append(os.path.abspath(os.path.join('..')))

from datasets import MRSDataset
import torch

# %%
root = '../data/'
train_dataset = MRSDataset(root, split='train')
train_dataloader = torch.utils.data.DataLoader(
    train_dataset,
    batch_size=16,
    shuffle=True,
    drop_last=True,
    num_workers=8
)

# %%
for step, batch in enumerate(train_dataloader):
    print(step, batch.shape)
# Out:
# 0 torch.Size([16, 512])
# 1 torch.Size([16, 512])
# 2 torch.Size([16, 512])
# 3 torch.Size([16, 512])
# 4 torch.Size([16, 512])
# 5 torch.Size([16, 512])
# 6 torch.Size([16, 512])
# 7 torch.Size([16, 512])
# 8 torch.Size([16, 512])
# 9 torch.Size([16, 512])
# 10 torch.Size([16, 512])
# 11 torch.Size([16, 512])
# 12 torch.Size([16, 512])
# 13 torch.Size([16, 512])
# 14 torch.Size([16, 512])
# 15 torch.Size([16, 512])
# 16 torch.Size([16, 512])
# 17 torch.Size([16, 512])
# 18 torch.Size([16, 512])
# 19 torch.Size([16, 512])
# 20 torch.Size([16, 512])
# 21 torch.Size([16, 512])
# 22 torch.Size([16, 512])
# 23 torch.Size([16, 512])
# 24 torch.Size([16, 512])
# 25 torch.Size([16, 512])
# 26 torch.Size([16, 512])
# 27 torch.Size([16, 512])
# 28 torch.Size([16, 512])
# 29 torch.Size([16, 512])
# 30 torch.Size([16, 512])
